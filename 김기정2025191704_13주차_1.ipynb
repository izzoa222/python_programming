# %% [markdown]
# <a href="https://colab.research.google.com/github/izzoa222/python_programming/blob/main/%EA%B9%80%EA%B8%B0%EC%A0%952025191704_13%EC%A3%BC%EC%B0%A8_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import xml.etree.ElementTree as et

from google.colab import drive
drive.mount('/content/gdrive')
example1 = "/content/gdrive/My Drive/Colab Notebooks/menu.xml"
file1 = open(example1, "r")

tree = et.parse(example1)
root = tree.getroot()
# Out:
# Mounted at /content/gdrive

# %%
print(root.tag)
# Out:
# menu

# %%
type(root)
# Out:
# xml.etree.ElementTree.Element

# %%
for child in root:
  print('tag:', child.tag, 'attribute:', child.attrib)
  for grandchild in child:
    print('\ttag:', grandchild.tag, 'attribute:', grandchild.attrib)
# Out:
# tag: breakfast attribute: {'hours': '7-11'}
# 	tag: item attribute: {'price': '$6.00'}
# 	tag: item attribute: {'price': '$4.00'}
# tag: lunch attribute: {'hours': '11-3'}
# 	tag: item attribute: {'price': '$5.00'}
# tag: dinner attribute: {'hours': '3-10'}
# 	tag: item attribute: {'price': '8.00'}

# %%
len(root)
# Out:
# 3

# %%
len(root[0])
# Out:
# 2

# %%
type(root[0])
# Out:
# xml.etree.ElementTree.Element

# %%
print(root[0])
print(root[0].get("hours"))
print(root[0].keys())
print(root[0].items())
# Out:
# <Element 'breakfast' at 0x79c924288ef0>
# 7-11
# ['hours']
# [('hours', '7-11')]

# %%
lunch = root.find("lunch")
print(lunch)
print(lunch.get("hours"))
print(lunch.keys())
print(lunch.items())
# Out:
# <Element 'lunch' at 0x79c924289170>
# 11-3
# ['hours']
# [('hours', '11-3')]

# %%
print(root[0].findall('item'))
# Out:
# [<Element 'item' at 0x79c92428b1f0>, <Element 'item' at 0x79c924289120>]

# %%
for item in root[0].findall('item'):
  print(item.get('price'))
  print(item.text)
# Out:
# $6.00
# breakfast burritos
# $4.00
# pancakes

# %%
import json
j1 = {"name":"홍길동", "birth":"0525", "age": 30}
j1
# Out:
# {'name': '홍길동', 'birth': '0525', 'age': 30}

# %%
json.dumps(j1)
# Out:
# '{"name": "\\ud64d\\uae38\\ub3d9", "birth": "0525", "age": 30}'

# %%
print(json.dumps(j1, indent=2))
# Out:
# {
#   "name": "\ud64d\uae38\ub3d9",
#   "birth": "0525",
#   "age": 30
# }

# %%
json.dumps([1,2,3])
# Out:
# '[1, 2, 3]'

# %%
json.dumps((4,5,6))
# Out:
# '[4, 5, 6]'

# %%
j1 = {"name":"홍길동", "birth":"0525", "age": 30}
d1 = json.dumps(j1)
json.loads(d1)
# Out:
# {'name': '홍길동', 'birth': '0525', 'age': 30}

# %%
myinfo = '{"name":"홍길동", "birth":"0525", "age": 30}'
data = json.loads(myinfo)
print(data)
# Out:
# {'name': '홍길동', 'birth': '0525', 'age': 30}

# %%
from urllib.request import urlopen

url = 'https://www.naver.com'
html = urlopen(url)
print(html.read())
# Out:
# b'   <!doctype html> <html lang="ko" class="fzoom"> <head> <meta charset="utf-8"> <meta name="Referrer" content="origin"> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <title>NAVER</title> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xeb\xa9\x94\xec\x9d\xb8\xec\x97\x90\xec\x84\x9c \xeb\x8b\xa4\xec\x96\x91\xed\x95\x9c \xec\xa0\x95\xeb\xb3\xb4\xec\x99\x80 \xec\x9c\xa0\xec\x9a\xa9\xed\x95\x9c \xec\xbb\xa8\xed\x85\x90\xec\xb8\xa0\xeb\xa5\xbc \xeb\xa7\x8c\xeb\x82\x98 \xeb\xb3\xb4\xec\x84\xb8\xec\x9a\x94"/> <meta property="og:title" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="\xeb\x84\xa4\xec\x
# ...

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
html = urlopen("https://www.naver.com")
bsObj = BeautifulSoup(html.read(), "html.parser")
print(bsObj.h1)
# Out:
# <h1 class="search_logo" id="special-input-logo"></h1>
